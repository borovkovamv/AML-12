# %% [markdown]
# ## Домашнее задание «Требования в DS проектах aml»

# %%
# Возьмите за основу продукт компании “Нетология” - профессию Data Scientist.
# Как бы Вы организовали аналитику по данному продукту?
# Сформулируйте 2-3 ключевые метрики продукта
# Какие данные Вам могут помочь в поиске инсайтов?
# Опишите команду для работы с данными для данного продукта
# Какие роли Вам будут нужны?
# Чем они будут заниматься?

# %% [markdown]
# Организовала бы аналитику через показатели:
# - количество оплативших курс в динамике год к году/квартал к кварталу
# - количество закончивших курс по отношению к количесту начавших в динамике (посмотрела бы сколько человек заинтересовано окончить курс)
# - средниче оценки отзывов учащихся на основании опросов в динамике (посмотрела мы становимся привлекательнее или контент необходимо менять)

# %% [markdown]
# В поиске инсайтов могут помочь другие ресурсы с отзывами об аналогичных курсах/продукте. Сайты конкурентов с доступной информацией.
# Преподаватели, которых переманить от конкурентов.
# Ученики, которые ранее обучались на других ресурсах.

# %% [markdown]
# Для работы с данными понадобятся:
# - продуктовый аналитик
# - data scientist
# - data engineer
# - руководитель проекта/продукта

# %% [markdown]
# Нужен человек, который будет собирать инсайты из разных источников интернета как о своем продукте, так и о продукте конкурентов.
# Еще нужен человек, который будет анализировать данные, выдвигать гипотезы, проверять их. Потом будет еще человек, который собирает все эти данные в хранилище, обеспечивает качество данных, резервирование, правильное хранение, быструю доставку до BI инструментов. И нужен руководитель группы, который будет координировать и оркестрировать работу этих людей.
